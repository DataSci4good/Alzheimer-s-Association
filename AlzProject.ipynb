# %%
#for EDA:
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

#for geocoding:
from pygeocoder import Geocoder
from pygeocoder import GeocoderError
import numpy as np
import time

# %matplotlib inline
pd.set_option('display.max_columns', 50)

# %%
#read in and concatenate the 3 excel files of call data
all_calls = pd.read_excel("datasci4good_2015-12-22_1_of_3.xls")\
                         .append(pd.read_excel("datasci4good_2015-12-22_2_of_3.xls"))\
                         .append(pd.read_excel("datasci4good_2015-12-22_3_of_3.xls"))

# %%
all_calls.shape
# Out:
# (47302, 23)

# %%
all_calls.head(3)
# Out:
#                                         Reason Case Note Date  \
# 0                                 Left Message     2015-12-22
# 1                     Home Care/Companion/Aide     2015-12-22
# 2  Training-Dementia Care Tx for Professionals     2015-12-22
#
#   [Caller] ZipCode [Caller] Title  [Caller] Mailing Address [Caller] City  \
# 0            10128            NaN  502 East 88th Street #5C      New York
# 1              NaN            NaN                       NaN           NaN
# 2              NaN            NaN                       NaN           NaN
#
#   [Caller] State Service [Caller] Borough Reason 2 [Caller] DOB  \
# 0             NY   Admin        Manhattan      NaN        Given
# 1             NY     I/R              NaN      NaN      Unknown
# 2             NY     I/R              NaN      NaN      Unknown
#
#   [Caller] Date of Birth Reason 3  [Caller] Age Reason 4 Reason 5  \
# 0    1955-05-06 00:00:00      NaN            60      NaN      NaN
# 1                    NaN      NaN           NaN      NaN      NaN
# 2                    NaN      NaN           NaN      NaN      NaN
#
#   [Caller] Gender            [Caller] Education Contact Type Location  \
# 0          Female               Bachelor Degree    Follow-up    Phone
# 1         Unknown  Not Appropriate for the call          New    Phone
# 2         Unknown  Not Appropriate for the call          New    Phone
#
#   [Caller] Race [Caller] Primary Language [Caller] Secondary Language
# 0         White                   English                         NaN
# 1       Unknown                   English                         NaN
# 2       Unknown                   English                         NaN

# %%
all_calls.rename(columns=lambda x: x.replace(" ","_"),inplace=True)
all_calls.rename(columns=lambda x: x.replace("[",""),inplace=True)
all_calls.rename(columns=lambda x: x.replace("]",""),inplace=True)

# %%
all_calls.columns.values
# Out:
# array([u'Reason', u'Case_Note_Date', u'Caller_ZipCode', u'Caller_Title',
#        u'Caller_Mailing_Address', u'Caller_City', u'Caller_State',
#        u'Service', u'Caller_Borough', u'Reason_2', u'Caller_DOB',
#        u'Caller_Date_of_Birth', u'Reason_3', u'Caller_Age', u'Reason_4',
#        u'Reason_5', u'Caller_Gender', u'Caller_Education', u'Contact_Type',
#        u'Location', u'Caller_Race', u'Caller_Primary_Language',
#        u'Caller_Secondary_Language'], dtype=object)

# %%
print sum(all_calls.Caller_Borough.value_counts())
all_calls.Caller_Borough.value_counts()
# Out:
# 33674
# Manhattan        12588
# Brooklyn          8192
# Queens            7439
# Bronx             4521
# Staten Island      934
# dtype: int64

# %%
sum(all_calls[all_calls.Caller_Borough == 'Staten Island'].Caller_Mailing_Address.isnull())
# Out:
# 72

# %%
all_calls.head(3)
# Out:
#                                         Reason Case_Note_Date Caller_ZipCode  \
# 0                                 Left Message     2015-12-22          10128
# 1                     Home Care/Companion/Aide     2015-12-22            NaN
# 2  Training-Dementia Care Tx for Professionals     2015-12-22            NaN
#
#   Caller_Title    Caller_Mailing_Address Caller_City Caller_State Service  \
# 0          NaN  502 East 88th Street #5C    New York           NY   Admin
# 1          NaN                       NaN         NaN           NY     I/R
# 2          NaN                       NaN         NaN           NY     I/R
#
#   Caller_Borough Reason_2 Caller_DOB Caller_Date_of_Birth Reason_3  \
# 0      Manhattan      NaN      Given  1955-05-06 00:00:00      NaN
# 1            NaN      NaN    Unknown                  NaN      NaN
# 2            NaN      NaN    Unknown                  NaN      NaN
#
#    Caller_Age Reason_4 Reason_5 Caller_Gender              Caller_Education  \
# 0          60      NaN      NaN        Female               Bachelor Degree
# 1         NaN      NaN      NaN       Unknown  Not Appropriate for the call
# 2         NaN      NaN      NaN       Unknown  Not Appropriate for the call
#
#   Contact_Type Location Caller_Race Caller_Primary_Language  \
# 0    Follow-up    Phone       White                 English
# 1          New    Phone     Unknown                 English
# 2          New    Phone     Unknown                 English
#
#   Caller_Secondary_Language
# 0                       NaN
# 1                       NaN
# 2                       NaN

# %%
sum(all_calls.Caller_Mailing_Address.isnull())
# Out:
# 9603

# %%
all_calls.Caller_State.value_counts()
# Out:
# NY    45220
# NJ      581
# CA      163
# MA      143
# FL      134
# CT      133
# NC      103
# PA       96
# MD       95
# TX       66
# VA       63
# DC       50
# GA       49
# NM       26
# SC       23
# CO       23
# OH       15
# MN       15
# WA       13
# ME       13
# OR       13
# AL       13
# IL       12
# RI       12
# AZ       11
# MI        9
# VT        9
# MO        6
# TN        6
# WV        3
# WI        3
# PR        3
# NV        3
# ND        2
# LA        2
# AR        1
# NU        1
# DE        1
# ID        1
# NH        1
# NL        1
# IN        1
# dtype: int64

# %%
all_calls.Caller_City.value_counts()
# Out:
# New York                  12475
# Brooklyn                   8618
# Bronx                      4792
# Staten Island               957
# Flushing                    895
# Jamaica                     761
# Forest Hills                545
# Astoria                     409
# Woodside                    369
# Jackson Heights             352
# Bayside                     291
# Elmhurst                    257
# East Elmhurst               236
# Far Rockaway                211
# Ridgewood                   203
# Rosedale                    200
# Rego Park                   186
# Long Island City            183
# Sunnyside                   174
# Fresh Meadows               166
# Corona                      156
# Howard Beach                156
# Kew Gardens                 155
# Queens Village              150
# NYC                         138
# Whitestone                  137
# Maspeth                     115
# Ozone Park                  112
# South Richmond Hill         106
# Springfield Gardens         106
#                           ...
# Amherst                       1
# South Ozone park              1
# Demarest                      1
# Barnegat                      1
# Deer Park, Long Island        1
# Greenlawn                     1
# Red Bank                      1
# Beverly                       1
# Dobbs Ferry                   1
# East Rockaway                 1
# Springfield Garden            1
# Putnam Valley                 1
# Beechurst                     1
# Ewing                         1
# Masbeth                       1
# Williamsburg                  1
# Schenevus                     1
# Long lsland                   1
# Montgomeryville               1
# St Paul                       1
# Pound Ridge                   1
# Tappan                        1
# Fresh Meadow                  1
# Whiting                       1
# everett                       1
# Williston                     1
# Sandpoint                     1
# Shrewsbury                    1
# Buffalo                       1
# Prosper                       1
# dtype: int64

# %%
ny_calls = all_calls[all_calls.Caller_State == 'NY']
ny_calls.Caller_City.value_counts()
# Out:
# New York                  12460
# Brooklyn                   8613
# Bronx                      4784
# Staten Island               957
# Flushing                    895
# Jamaica                     761
# Forest Hills                545
# Astoria                     405
# Woodside                    369
# Jackson Heights             352
# Bayside                     291
# Elmhurst                    257
# East Elmhurst               236
# Far Rockaway                211
# Rosedale                    200
# Ridgewood                   196
# Rego Park                   186
# Long Island City            183
# Sunnyside                   174
# Fresh Meadows               166
# Corona                      156
# Howard Beach                156
# Kew Gardens                 155
# Queens Village              150
# NYC                         138
# Whitestone                  137
# Maspeth                     115
# Ozone Park                  112
# Woodhaven                   106
# Springfield Gardens         106
#                           ...
# Croton-on-Hudson              1
# Millwood                      1
# Williamsburg                  1
# Long Island                   1
# Putnam Valley                 1
# East Rockaway                 1
# Warwick                       1
# Greenlawn                     1
# Bron                          1
# Peoria                        1
# Woodheaven                    1
# Garner Ville                  1
# Ditmas Park                   1
# New York, Astoria             1
# Long Valley                   1
# Peekskill                     1
# Getzville                     1
# Hudson                        1
# Sleepy Hollow                 1
# Hawthorne                     1
# Carona                        1
# Lynbrook                      1
# Deer Park, Long Island        1
# South Salem                   1
# Manhasset                     1
# East Patchogue                1
# Richmond Hills                1
# Uniondale                     1
# Victor                        1
# Mount Kisco                   1
# dtype: int64

# %%
sns.countplot(x="Caller_Borough", data=all_calls, palette="Greens_d")

# %%
###########
#Here's the code to read in a single excel file and make a call to google for the geocodes, 2300 per execution,
#one address per call:
###########

# %%
#read in one excel file of call data
all_calls = pd.read_excel("datasci4good_2015-12-22_1_of_3.xls")
                         #Tamara to take: ("datasci4good_2015-12-22_2_of_3.xls"))\
                         #Gordon or Brian to take:("datasci4good_2015-12-22_3_of_3.xls"))

# %%
#rename columns so they are easier to work with
all_calls.rename(columns=lambda x: x.replace(" ","_"),inplace=True)
all_calls.rename(columns=lambda x: x.replace("[",""),inplace=True)
all_calls.rename(columns=lambda x: x.replace("]",""),inplace=True)

# %%
#add columns for id number in case we ever have to put the records back in the original order
num_file = 1 #change to 2 and 3 for 2nd and 3rd files
all_calls['file_num'] = num_file
rec_num = range(0,len(all_calls),1)
all_calls['rec_id'] = rec_num

# %%
all_calls.head()
# Out:
#                                         Reason Case_Note_Date Caller_ZipCode  \
# 0                                 Left Message     2015-12-22          10128
# 1                     Home Care/Companion/Aide     2015-12-22            NaN
# 2  Training-Dementia Care Tx for Professionals     2015-12-22            NaN
# 3                       MTG-Medicaid Home Care     2015-12-22          10023
# 4                   MTG-Understanding Dementia     2015-12-22            NaN
#
#   Caller_Title       Caller_Mailing_Address Caller_City Caller_State  \
# 0          NaN     502 East 88th Street #5C    New York           NY
# 1          NaN                          NaN         NaN           NY
# 2          NaN                          NaN         NaN           NY
# 3          NaN  44  West 62 Street, Apt. 8D    New York           NY
# 4          NaN                          NaN         NaN           NY
#
#        Service Caller_Borough  Reason_2 Caller_DOB Caller_Date_of_Birth  \
# 0        Admin      Manhattan       NaN      Given           1955-05-06
# 1          I/R            NaN       NaN    Unknown                  NaT
# 2          I/R            NaN       NaN    Unknown                  NaT
# 3  Social Work      Manhattan  Planning      Given           1940-01-01
# 4          I/R      Manhattan       NaN    Unknown                  NaT
#
#   Reason_3  Caller_Age Reason_4 Reason_5 Caller_Gender  \
# 0      NaN          60      NaN      NaN        Female
# 1      NaN         NaN      NaN      NaN       Unknown
# 2      NaN         NaN      NaN      NaN       Unknown
# 3      NaN          75      NaN      NaN        Female
# 4      NaN         NaN      NaN      NaN          Male
#
#                Caller_Education Contact_Type Location Caller_Race  \
# 0               Bachelor Degree    Follow-up    Phone       White
# 1  Not Appropriate for the call          New    Phone     Unknown
# 2  Not Appropriate for the call          New    Phone     Unknown
# 3  Not Appropriate for the call    Follow-up   Office     Unknown
# 4  Not Appropriate for the call          New    Phone     Unknown
#
#   Caller_Primary_Language Caller_Secondary_Language  file_num  rec_id
# 0                 English                       NaN         1       0
# 1                 English                       NaN         1       1
# 2                 English                       NaN         1       2
# 3                 English                       NaN         1       3
# 4                 English                       NaN         1       4

# %%
###########
#First some code to weed out the invalid addresses (i.e. those missing 2 of 3 address fields)
###########

# %%
#check where the floats are that are messing up the map function a few cells down.  Python raises an error
#when it tries to take the len of a float.  ie len(NaN)
all_calls['addrTuple'] = zip(all_calls.Caller_Mailing_Address,all_calls.Caller_City, all_calls.Caller_State)
floats = map(lambda x: (type(x[0]) == float) |(type(x[1]) == float) |(type(x[2]) == float), all_calls.addrTuple)
all_calls[floats]
# Out:
#                                             Reason Case_Note_Date  \
# 1                         Home Care/Companion/Aide     2015-12-22
# 2      Training-Dementia Care Tx for Professionals     2015-12-22
# 4                       MTG-Understanding Dementia     2015-12-22
# 6                                     Left Message     2015-12-22
# 7                                     Left Message     2015-12-18
# 8                                            Other     2015-12-22
# 9                 Case Management/CG Services/DFTA     2015-12-22
# 13                                    Left Message     2015-12-22
# 15                                    Alz NYC Info     2015-12-22
# 16                        CG Stress/Needed to Talk     2015-12-22
# 19                      MTG-Understanding Dementia     2015-12-22
# 21                     MTG-Monthly Educational Mtg     2015-12-22
# 22                                   Support Group     2015-12-22
# 27      MTG-Moving Your Relative to A Nursing Home     2015-12-22
# 32      MTG-Moving Your Relative to A Nursing Home     2015-12-22
# 36                                    Alz NYC Info     2015-12-22
# 40                             MTG-Legal/Financial     2015-12-22
# 43      MTG-Moving Your Relative to A Nursing Home     2015-12-22
# 47                     MTG-Monthly Educational Mtg     2015-12-21
# 54              Training-Family Caregiver Workshop     2015-12-21
# 56                                        Planning     2015-12-21
# 58                                 Late Stage Care     2015-12-21
# 59                      MTG-Understanding Dementia     2015-12-21
# 66     Training-Dementia Care Tx for Professionals     2015-12-21
# 72                      MTG-Understanding Dementia     2015-12-21
# 75                                      Activities     2015-12-21
# 81     Training-Dementia Care Tx for Professionals     2015-12-10
# 82     Training-Dementia Care Tx for Professionals     2015-12-21
# 93                                           Other     2015-12-17
# 94                                       Donations     2015-12-17
# ...                                            ...            ...
# 16649                                 Alz NYC Info     2015-03-06
# 16650                                Support Group     2015-03-06
# 16651                  MTG-Monthly Educational Mtg     2015-03-04
# 16652                                 Alz NYC Info     2015-03-05
# 16653                                 Alz NYC Info     2015-03-05
# 16654                                Support Group     2015-03-03
# 16655                                Support Group     2015-03-01
# 16656                                Support Group     2015-02-26
# 16657                                Support Group     2015-02-25
# 16658                                 Alz NYC Info     2015-02-23
# 16659                                 Alz NYC Info     2015-02-23
# 16661                                 Alz NYC Info     2015-03-23
# 16662                                 Alz NYC Info     2015-02-23
# 16663                                 Alz NYC Info     2015-02-23
# 16667                             Medic Alert  NYC     2015-03-05
# 16676                     CG Stress/Needed to Talk     2015-03-04
# 16680                              Family Conflict     2015-03-04
# 16684                         Early Stage Services     2015-03-02
# 16685                         Early Stage Services     2015-03-03
# 16686                         Early Stage Services     2015-02-11
# 16691                              Legal/Financial     2015-03-05
# 16697                                 Left Message     2015-03-05
# 16698                                 Left Message     2015-03-05
# 16701                                    Donations     2015-03-05
# 16703                                     Planning     2015-02-20
# 16705                                Support Group     2015-03-05
# 16708                          MTG-Legal/Financial     2015-03-05
# 16709                           togetherwecare.com     2015-03-05
# 16710                                    Donations     2015-03-05
# 16711                           togetherwecare.com     2015-03-05
#
#       Caller_ZipCode Caller_Title Caller_Mailing_Address        Caller_City  \
# 1                NaN          NaN                    NaN                NaN
# 2                NaN          NaN                    NaN                NaN
# 4                NaN          NaN                    NaN                NaN
# 6                NaN          NaN                    NaN                NaN
# 7                NaN          NaN                    NaN                NaN
# 8                NaN          NaN                    NaN                NaN
# 9                NaN          NaN                    NaN                NaN
# 13               NaN          NaN                    NaN                NaN
# 15               NaN          NaN                    NaN                NaN
# 16             11233          NaN                    NaN                NaN
# 19             10128          NaN                    NaN                NaN
# 21               NaN          NaN                    NaN                NaN
# 22               NaN          NaN                    NaN                NaN
# 27               NaN          NaN                    NaN                NaN
# 32               NaN          NaN                    NaN                NaN
# 36               NaN          NaN                    NaN                NaN
# 40               NaN          NaN                    NaN                NaN
# 43             10001          NaN       290 9th Ave #10F                NaN
# 47               NaN          NaN                    NaN                NaN
# 54               NaN          NaN                    NaN                NaN
# 56               NaN          NaN                    NaN                NaN
# 58               NaN          NaN                    NaN                NaN
# 59             10128          NaN                    NaN                NaN
# 66             10458          NaN      2965 Decatur Ave.                NaN
# 72             11360          NaN                    NaN            Bayside
# 75               NaN          NaN                    NaN                NaN
# 81             11369          NaN                    NaN                NaN
# 82               NaN          NaN                    NaN                NaN
# 93               NaN          NaN                    NaN                NaN
# 94               NaN          NaN                    NaN                NaN
# ...              ...          ...                    ...                ...
# 16649            NaN          NaN                    NaN                NaN
# 16650            NaN          NaN                    NaN                NaN
# 16651            NaN          NaN                    NaN                NaN
# 16652            NaN          NaN                    NaN                NaN
# 16653            NaN          NaN                    NaN                NaN
# 16654            NaN          NaN                    NaN                NaN
# 16655            NaN          NaN                    NaN                NaN
# 16656            NaN          NaN                    NaN                NaN
# 16657            NaN          NaN                    NaN                NaN
# 16658            NaN          NaN                    NaN                NaN
# 16659            NaN          NaN                    NaN                NaN
# 16661            NaN          NaN                    NaN                NaN
# 16662            NaN          NaN                    NaN                NaN
# 16663            NaN          NaN                    NaN                NaN
# 16667            NaN          NaN                    NaN                NaN
# 16676          10454          NaN                    NaN                NaN
# 16680          34983          NaN                    NaN                NaN
# 16684            NaN          NaN                    NaN                NaN
# 16685            NaN          NaN                    NaN                NaN
# 16686            NaN          NaN                    NaN                NaN
# 16691            NaN          NaN                    NaN                NaN
# 16697          77459          NaN                    NaN  Sienna Plantation
# 16698          77459          NaN                    NaN  Sienna Plantation
# 16701            NaN          NaN                    NaN                NaN
# 16703            NaN          NaN                    NaN                NaN
# 16705            NaN          NaN                    NaN                NaN
# 16708            NaN          NaN                    NaN                NaN
# 16709            NaN          NaN                    NaN                NaN
# 16710            NaN          NaN                    NaN                NaN
# 16711            NaN          NaN                    NaN                NaN
#
#       Caller_State                             Service Caller_Borough  \
# 1               NY                                 I/R            NaN
# 2               NY                                 I/R            NaN
# 4               NY                                 I/R      Manhattan
# 6               NY                               Admin            NaN
# 7               NY                               Admin            NaN
# 8               NY                                 I/R            NaN
# 9               NY                                 I/R            NaN
# 13              NY                               Admin            NaN
# 15              NY                                 I/R            NaN
# 16              NY                         Social Work       Brooklyn
# 19              NY                                 I/R            NaN
# 21              NY                                 I/R            NaN
# 22              NY                                 I/R            NaN
# 27              NY                                 I/R            NaN
# 32              NY                     Tunstall Report            NaN
# 36              NY                     Tunstall Report            NaN
# 40              NY                                 I/R            NaN
# 43              NY                                 I/R      Manhattan
# 47              NY                                 I/R      Manhattan
# 54              NY                                 I/R            NaN
# 56              NY                         Social Work      Manhattan
# 58             NaN                                 I/R            NaN
# 59              NY                                 I/R            NaN
# 66              NY                                 I/R          Bronx
# 72              NY                                 I/R         Queens
# 75              NY                                 I/R      Manhattan
# 81              NY                                 I/R         Queens
# 82              NY                                 I/R            NaN
# 93              NY                               Admin            NaN
# 94              NY                     Tunstall Report            NaN
# ...            ...                                 ...            ...
# 16649           NY                                 I/R            NaN
# 16650           NY                                 I/R            NaN
# 16651           NY                                 I/R            NaN
# 16652           NY                                 I/R            NaN
# 16653           NY                                 I/R            NaN
# 16654           NY                                 I/R            NaN
# 16655           NY                                 I/R            NaN
# 16656           NY                                 I/R            NaN
# 16657           NY                                 I/R            NaN
# 16658           NY                                 I/R            NaN
# 16659           NY                                 I/R            NaN
# 16661           NY                                 I/R            NaN
# 16662           NY                                 I/R            NaN
# 16663           NY                                 I/R            NaN
# 16667           NY                Contact Center - I/R            NaN
# 16676           NY  Contact Center - Care Consultation            NaN
# 16680           FL  Contact Center - Care Consultation            NaN
# 16684           NY                 Care Consultation 1            NaN
# 16685           NY                                 I/R      Manhattan
# 16686           NY                                 I/R      Manhattan
# 16691           NY                Contact Center - I/R            NaN
# 16697           NY                               Admin            NaN
# 16698           NY                               Admin            NaN
# 16701           NY                Contact Center - I/R            NaN
# 16703           VT                 Care Consultation 1            NaN
# 16705           NY                Contact Center - I/R            NaN
# 16708           NY                                 I/R            NaN
# 16709           NY                                 I/R            NaN
# 16710           NY                Contact Center - I/R            NaN
# 16711           NY                                 I/R            NaN
#
#                          Reason_2 Caller_DOB Caller_Date_of_Birth  \
# 1                             NaN    Unknown                  NaT
# 2                             NaN    Unknown                  NaT
# 4                             NaN    Unknown                  NaT
# 6                             NaN    Unknown                  NaT
# 7                             NaN    Unknown                  NaT
# 8                             NaN    Unknown                  NaT
# 9                             NaN    Unknown                  NaT
# 13                            NaN    Unknown                  NaT
# 15                            NaN    Unknown                  NaT
# 16                            NaN      Given           1993-01-01
# 19                            NaN    Refused                  NaT
# 21                            NaN    Unknown                  NaT
# 22                            NaN    Unknown                  NaT
# 27                            NaN    Unknown                  NaT
# 32                            NaN    Unknown                  NaT
# 36                            NaN    Unknown                  NaT
# 40     MTG-Understanding Dementia    Unknown                  NaT
# 43                            NaN    Unknown                  NaT
# 47                            NaN    Unknown                  NaT
# 54                            NaN    Unknown                  NaT
# 56                            NaN    Unknown                  NaT
# 58                            NaN        NaN                  NaT
# 59                            NaN    Refused                  NaT
# 66                            NaN    Unknown                  NaT
# 72                  Support Group      Given           1955-01-01
# 75      LTC Facility/Nursing Home    Unknown                  NaT
# 81                            NaN      Given           1964-09-01
# 82                            NaN    Unknown                  NaT
# 93                            NaN    Unknown                  NaT
# 94                            NaN    Unknown                  NaT
# ...                           ...        ...                  ...
# 16649                         NaN    Unknown                  NaT
# 16650                         NaN    Unknown                  NaT
# 16651                         NaN    Unknown                  NaT
# 16652                         NaN    Unknown                  NaT
# 16653                         NaN    Unknown                  NaT
# 16654                Volunteering    Unknown                  NaT
# 16655                Volunteering    Unknown                  NaT
# 16656                         NaN    Unknown                  NaT
# 16657                         NaN    Unknown                  NaT
# 16658                         NaN    Unknown                  NaT
# 16659                         NaN    Unknown                  NaT
# 16661                         NaN    Unknown                  NaT
# 16662                         NaN    Unknown                  NaT
# 16663                         NaN    Unknown                  NaT
# 16667                         NaN    Unknown                  NaT
# 16676                   Diagnosis    Unknown                  NaT
# 16680                         NaN    Unknown                  NaT
# 16684                         NaN    Unknown                  NaT
# 16685                         NaN    Unknown                  NaT
# 16686                         NaN    Unknown                  NaT
# 16691                         NaN    Unknown                  NaT
# 16697                         NaN    Unknown                  NaT
# 16698                         NaN    Unknown                  NaT
# 16701                         NaN    Unknown                  NaT
# 16703    CG Stress/Needed to Talk    Unknown                  NaT
# 16705                         NaN    Unknown                  NaT
# 16708                         NaN    Unknown                  NaT
# 16709                         NaN    Unknown                  NaT
# 16710                         NaN    Unknown                  NaT
# 16711                         NaN    Unknown                  NaT
#
#                                           Reason_3  Caller_Age Reason_4  \
# 1                                              NaN         NaN      NaN
# 2                                              NaN         NaN      NaN
# 4                                              NaN         NaN      NaN
# 6                                              NaN         NaN      NaN
# 7                                              NaN         NaN      NaN
# 8                                              NaN         NaN      NaN
# 9                                              NaN         NaN      NaN
# 13                                             NaN         NaN      NaN
# 15                                             NaN         NaN      NaN
# 16                                             NaN          22      NaN
# 19                                             NaN         NaN      NaN
# 21                                             NaN         NaN      NaN
# 22                                             NaN         NaN      NaN
# 27                                             NaN         NaN      NaN
# 32                                             NaN         NaN      NaN
# 36                                             NaN         NaN      NaN
# 40     Training-Dementia Care Tx for Professionals         NaN      NaN
# 43                                             NaN         NaN      NaN
# 47                                             NaN         NaN      NaN
# 54                                             NaN         NaN      NaN
# 56                                             NaN         NaN      NaN
# 58                                             NaN         NaN      NaN
# 59                                             NaN         NaN      NaN
# 66                                             NaN         NaN      NaN
# 72                                             NaN          60      NaN
# 75                                             NaN         NaN      NaN
# 81                                             NaN          51      NaN
# 82                                             NaN         NaN      NaN
# 93                                             NaN         NaN      NaN
# 94                                             NaN         NaN      NaN
# ...                                            ...         ...      ...
# 16649                                          NaN         NaN      NaN
# 16650                                          NaN         NaN      NaN
# 16651                                          NaN         NaN      NaN
# 16652                                          NaN         NaN      NaN
# 16653                                          NaN         NaN      NaN
# 16654                                          NaN         NaN      NaN
# 16655                                          NaN         NaN      NaN
# 16656                                          NaN         NaN      NaN
# 16657                                          NaN         NaN      NaN
# 16658                                          NaN         NaN      NaN
# 16659                                          NaN         NaN      NaN
# 16661                                          NaN         NaN      NaN
# 16662                                          NaN         NaN      NaN
# 16663                                          NaN         NaN      NaN
# 16667                                          NaN         NaN      NaN
# 16676                                          NaN         NaN      NaN
# 16680                                          NaN         NaN      NaN
# 16684                                          NaN         NaN      NaN
# 16685                                          NaN         NaN      NaN
# 16686                                          NaN         NaN      NaN
# 16691                                          NaN         NaN      NaN
# 16697                                          NaN         NaN      NaN
# 16698                                          NaN         NaN      NaN
# 16701                                          NaN         NaN      NaN
# 16703                         Early Stage Services         NaN      NaN
# 16705                                          NaN         NaN      NaN
# 16708                                          NaN         NaN      NaN
# 16709                                          NaN         NaN      NaN
# 16710                                          NaN         NaN      NaN
# 16711                                          NaN         NaN      NaN
#
#       Reason_5 Caller_Gender              Caller_Education Contact_Type  \
# 1          NaN       Unknown  Not Appropriate for the call          New
# 2          NaN       Unknown  Not Appropriate for the call          New
# 4          NaN          Male  Not Appropriate for the call          New
# 6          NaN        Female  Not Appropriate for the call    Follow-up
# 7          NaN        Female  Not Appropriate for the call          New
# 8          NaN       Unknown  Not Appropriate for the call          New
# 9          NaN       Unknown  Not Appropriate for the call          New
# 13         NaN        Female  Not Appropriate for the call    Follow-up
# 15         NaN       Unknown  Not Appropriate for the call          New
# 16         NaN        Female               Bachelor Degree    Follow-up
# 19         NaN        Female  Not Appropriate for the call    Follow-up
# 21         NaN        Female  Not Appropriate for the call    Follow-up
# 22         NaN       Unknown  Not Appropriate for the call          New
# 27         NaN          Male  Not Appropriate for the call    Follow-up
# 32         NaN          Male  Not Appropriate for the call    Follow-up
# 36         NaN          Male  Not Appropriate for the call    Follow-up
# 40         NaN       Unknown  Not Appropriate for the call          New
# 43         NaN        Female  Not Appropriate for the call    Follow-up
# 47         NaN        Female  Not Appropriate for the call    Follow-up
# 54         NaN       Unknown  Not Appropriate for the call          New
# 56         NaN        Female  Not Appropriate for the call    Follow-up
# 58         NaN           NaN                           NaN    Follow-up
# 59         NaN        Female  Not Appropriate for the call    Follow-up
# 66         NaN        Female  Not Appropriate for the call          New
# 72         NaN        Female      Post/Professional Degree    Follow-up
# 75         NaN        Female  Not Appropriate for the call          New
# 81         NaN        Female  Not Appropriate for the call    Follow-up
# 82         NaN        Female  Not Appropriate for the call    Follow-up
# 93         NaN       Unknown  Not Appropriate for the call    Follow-up
# 94         NaN       Unknown  Not Appropriate for the call          New
# ...        ...           ...                           ...          ...
# 16649      NaN       Unknown  Not Appropriate for the call          New
# 16650      NaN       Unknown  Not Appropriate for the call          New
# 16651      NaN        Female  Not Appropriate for the call          New
# 16652      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16653      NaN       Unknown  Not Appropriate for the call          New
# 16654      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16655      NaN       Unknown  Not Appropriate for the call          New
# 16656      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16657      NaN       Unknown  Not Appropriate for the call          New
# 16658      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16659      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16661      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16662      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16663      NaN       Unknown  Not Appropriate for the call          New
# 16667      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16676      NaN        Female  Not Appropriate for the call    Follow-up
# 16680      NaN        Female  Not Appropriate for the call    Follow-up
# 16684      NaN        Female  Not Appropriate for the call    Follow-up
# 16685      NaN        Female  Not Appropriate for the call    Follow-up
# 16686      NaN        Female  Not Appropriate for the call    Follow-up
# 16691      NaN       Unknown  Not Appropriate for the call          New
# 16697      NaN        Female  Not Appropriate for the call    Follow-up
# 16698      NaN        Female  Not Appropriate for the call    Follow-up
# 16701      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16703      NaN        Female  Not Appropriate for the call    Follow-up
# 16705      NaN       Unknown  Not Appropriate for the call          New
# 16708      NaN          Male  Not Appropriate for the call          New
# 16709      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16710      NaN       Unknown  Not Appropriate for the call    Follow-up
# 16711      NaN       Unknown  Not Appropriate for the call          New
#
#       Location               Caller_Race Caller_Primary_Language  \
# 1        Phone                   Unknown                 English
# 2        Phone                   Unknown                 English
# 4        Phone                   Unknown                 English
# 6        Phone           Hispanic/Latino                 Spanish
# 7        Phone           Hispanic/Latino                 Spanish
# 8        Phone                   Unknown                 English
# 9        Phone                   Unknown                 English
# 13       Phone  Not appropriate for call                 English
# 15       Phone                   Unknown                 English
# 16      E-mail    Black/African American                 English
# 19      E-mail                   Refused                 English
# 21      E-mail                   Unknown                 English
# 22       Phone                   Unknown                 English
# 27       Phone                   Unknown                 English
# 32       Phone                   Unknown                 English
# 36       Phone                   Unknown                 English
# 40       Phone                   Unknown                 English
# 43       Phone                     Other                 English
# 47      E-mail                   Unknown                 English
# 54       Phone                   Unknown                 English
# 56       Phone                   Unknown                 English
# 58       Phone                       NaN                     NaN
# 59       Phone                   Refused                 English
# 66      Office                   Unknown                 English
# 72       Phone                     White                 English
# 75       Phone                   Unknown                 English
# 81      Office           Hispanic/Latino                 Spanish
# 82       Phone  Not appropriate for call                 English
# 93       Phone                   Unknown                 English
# 94       Phone                   Unknown                 English
# ...        ...                       ...                     ...
# 16649    Phone                   Unknown                 English
# 16650    Phone                   Unknown                 English
# 16651   E-mail                   Unknown                 English
# 16652   E-mail                   Unknown                 English
# 16653   E-mail                   Unknown                 English
# 16654   E-mail                   Unknown                 English
# 16655   E-mail                   Unknown                 English
# 16656   E-mail                   Unknown                 English
# 16657   E-mail                   Unknown                 English
# 16658   E-mail                   Unknown                 English
# 16659   E-mail                   Unknown                 English
# 16661   E-mail                   Unknown                 English
# 16662   E-mail                   Unknown                 English
# 16663   E-mail                   Unknown                 English
# 16667    Phone                   Unknown                 English
# 16676    Phone                   Unknown                 English
# 16680    Phone           Hispanic/Latino                 English
# 16684    Phone  Not appropriate for call                 English
# 16685   E-mail  Not appropriate for call                 English
# 16686   E-mail  Not appropriate for call                 English
# 16691    Phone                   Unknown                 English
# 16697    Phone                   Unknown                 English
# 16698    Phone                   Unknown                 English
# 16701    Phone                   Unknown                 English
# 16703    Phone                   Unknown                 English
# 16705    Phone                   Unknown                 English
# 16708    Phone                   Unknown                 English
# 16709    Phone                   Unknown                 English
# 16710    Phone                   Unknown                 English
# 16711    Phone                   Unknown                 English
#
#       Caller_Secondary_Language  file_num  rec_id  \
# 1                           NaN         1       1
# 2                           NaN         1       2
# 4                           NaN         1       4
# 6                           NaN         1       6
# 7                           NaN         1       7
# 8                           NaN         1       8
# 9                           NaN         1       9
# 13                          NaN         1      13
# 15                          NaN         1      15
# 16                          NaN         1      16
# 19                          NaN         1      19
# 21                          NaN         1      21
# 22                          NaN         1      22
# 27                          NaN         1      27
# 32                          NaN         1      32
# 36                          NaN         1      36
# 40                          NaN         1      40
# 43                          NaN         1      43
# 47                          NaN         1      47
# 54                          NaN         1      54
# 56                          NaN         1      56
# 58                          NaN         1      58
# 59                          NaN         1      59
# 66                          NaN         1      66
# 72                          NaN         1      72
# 75                          NaN         1      75
# 81                          NaN         1      81
# 82                          NaN         1      82
# 93                          NaN         1      93
# 94                          NaN         1      94
# ...                         ...       ...     ...
# 16649                       NaN         1   16649
# 16650                       NaN         1   16650
# 16651                       NaN         1   16651
# 16652                       NaN         1   16652
# 16653                       NaN         1   16653
# 16654                       NaN         1   16654
# 16655                       NaN         1   16655
# 16656                       NaN         1   16656
# 16657                       NaN         1   16657
# 16658                       NaN         1   16658
# 16659                       NaN         1   16659
# 16661                       NaN         1   16661
# 16662                       NaN         1   16662
# 16663                       NaN         1   16663
# 16667                       NaN         1   16667
# 16676                       NaN         1   16676
# 16680                       NaN         1   16680
# 16684                       NaN         1   16684
# 16685                       NaN         1   16685
# 16686                       NaN         1   16686
# 16691                       NaN         1   16691
# 16697                       NaN         1   16697
# 16698                       NaN         1   16698
# 16701                       NaN         1   16701
# 16703                       NaN         1   16703
# 16705                       NaN         1   16705
# 16708                       NaN         1   16708
# 16709                       NaN         1   16709
# 16710                       NaN         1   16710
# 16711                       NaN         1   16711
#
#                           addrTuple
# 1                    (nan, nan, NY)
# 2                    (nan, nan, NY)
# 4                    (nan, nan, NY)
# 6                    (nan, nan, NY)
# 7                    (nan, nan, NY)
# 8                    (nan, nan, NY)
# 9                    (nan, nan, NY)
# 13                   (nan, nan, NY)
# 15                   (nan, nan, NY)
# 16                   (nan, nan, NY)
# 19                   (nan, nan, NY)
# 21                   (nan, nan, NY)
# 22                   (nan, nan, NY)
# 27                   (nan, nan, NY)
# 32                   (nan, nan, NY)
# 36                   (nan, nan, NY)
# 40                   (nan, nan, NY)
# 43      (290 9th Ave #10F, nan, NY)
# 47                   (nan, nan, NY)
# 54                   (nan, nan, NY)
# 56                   (nan, nan, NY)
# 58                  (nan, nan, nan)
# 59                   (nan, nan, NY)
# 66     (2965 Decatur Ave., nan, NY)
# 72               (nan, Bayside, NY)
# 75                   (nan, nan, NY)
# 81                   (nan, nan, NY)
# 82                   (nan, nan, NY)
# 93                   (nan, nan, NY)
# 94                   (nan, nan, NY)
# ...                             ...
# 16649                (nan, nan, NY)
# 16650                (nan, nan, NY)
# 16651                (nan, nan, NY)
# 16652                (nan, nan, NY)
# 16653                (nan, nan, NY)
# 16654                (nan, nan, NY)
# 16655                (nan, nan, NY)
# 16656                (nan, nan, NY)
# 16657                (nan, nan, NY)
# 16658                (nan, nan, NY)
# 16659                (nan, nan, NY)
# 16661                (nan, nan, NY)
# 16662                (nan, nan, NY)
# 16663                (nan, nan, NY)
# 16667                (nan, nan, NY)
# 16676                (nan, nan, NY)
# 16680                (nan, nan, FL)
# 16684                (nan, nan, NY)
# 16685                (nan, nan, NY)
# 16686                (nan, nan, NY)
# 16691                (nan, nan, NY)
# 16697  (nan, Sienna Plantation, NY)
# 16698  (nan, Sienna Plantation, NY)
# 16701                (nan, nan, NY)
# 16703                (nan, nan, VT)
# 16705                (nan, nan, NY)
# 16708                (nan, nan, NY)
# 16709                (nan, nan, NY)
# 16710                (nan, nan, NY)
# 16711                (nan, nan, NY)
#
# [4164 rows x 26 columns]

# %%
#replace the NaNs with empty strings.  The NaNs generated an error in the map function below when I tried to get the 
#len of the value NaN
all_calls.Caller_Mailing_Address = all_calls.Caller_Mailing_Address.fillna("")
all_calls.Caller_City = all_calls.Caller_City.fillna("")
all_calls.Caller_State = all_calls.Caller_State.fillna("")

# %%
#floats(aka NaNs) should be gone now
all_calls['addrTuple'] = zip(all_calls.Caller_Mailing_Address,all_calls.Caller_City, all_calls.Caller_State)
floats = map(lambda x: (type(x[0]) == float) |(type(x[1]) == float) |(type(x[2]) == float), all_calls.addrTuple)
all_calls[floats]
# Out:
# Empty DataFrame
# Columns: [Reason, Case_Note_Date, Caller_ZipCode, Caller_Title, Caller_Mailing_Address, Caller_City, Caller_State, Service, Caller_Borough, Reason_2, Caller_DOB, Caller_Date_of_Birth, Reason_3, Caller_Age, Reason_4, Reason_5, Caller_Gender, Caller_Education, Contact_Type, Location, Caller_Race, Caller_Primary_Language, Caller_Secondary_Language, file_num, rec_id, addrTuple]
# Index: []

# %%
#concatenate the address fields into one string to simplify the eventual request to google
all_calls['addrStr'] = all_calls.Caller_Mailing_Address + ","+ all_calls.Caller_City + "," + all_calls.Caller_State

# %%
# pull records from all_calls where there is a non-null address, will get geocode on those

#will consider an address with either a street and city or a city and state to be a non-null address
#but this doesn't filter out other types of invalid addresses;  
#the getGeo function should really handle those...someday

nonnullAddr = all_calls.addrTuple.map(lambda x: (((len(x[0]) > 0) & (len(x[1]) > 0))) \
                                      | ((len(x[1]) > 0) & (len(x[2]) > 0)))

print len(nonnullAddr)
print sum(nonnullAddr)
callstoGeo = all_calls[nonnullAddr]
print "toGeo: ", callstoGeo.shape
callstonotGeo = all_calls[-nonnullAddr]
print "tonotGeo:", callstonotGeo.shape
# Out:
# 16712
# 12894
# toGeo:  (12894, 27)
# tonotGeo: (3818, 27)

# %%
#function that slows down the request rate so that google doesn't reject them 
#should really be written as a try and except clause that catches over limit error as well as invalid address
#but this will do for now

#function that slows down the request rate so that google doesn't reject me 
#also allows google to return an empty result
def getGeo(addr):
    try:
        time.sleep(1)
        res = Geocoder.geocode(addr)
    except GeocoderError:  #really needs to catch the over limit error but will worry about that another day
        res = Geocoder.geocode("1600 Pennsylvania Ave, Washington, DC") #total hack
        
    return res

# %%
#I just changed the row numbers every time I ran this because I did not
#know when my daily limit would be up.  I ran a few hundred rows at a time when I did this for weeSpring.
#I tried it out on 20 rows this morning.
callstoGeoToday = callstoGeo.iloc[0:19,:]
callstoGeoToday['geocodes'] = callstoGeoToday['addrStr'].map(lambda x: getGeo(x)).map(lambda y: y.coordinates)
callstoGeoToday['geocodes']
# Out:
# /Users/tamaraosifchin/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0     (40.7768913, -73.9458435)
# 3     (40.7707725, -73.9830891)
# 5     (40.7347101, -73.9768136)
# 10    (40.8351788, -73.8877463)
# 11    (40.6942798, -73.9522966)
# 12    (40.6942798, -73.9522966)
# 14      (40.604977, -74.000585)
# 17     (40.593222, -73.7552989)
# 18    (40.7400237, -74.0093172)
# 20      (40.653732, -73.935719)
# 23      (40.836458, -73.946154)
# 24     (40.777937, -73.7820071)
# 25        (40.8083, -73.951389)
# 26    (40.7127837, -74.0059413)
# 28    (40.6565587, -74.0127747)
# 29      (40.733503, -73.979681)
# 30      (40.733503, -73.979681)
# 31      (40.635312, -73.912573)
# 33    (40.7081634, -73.7905933)
# Name: geocodes, dtype: object

# %%
#save each batch of data to a csv
callstoGeoToday.to_csv('callsFromFile1Rows0to19.csv',index=False)

# %%
print callstoGeoToday.shape
callstoGeoToday.head(3)
# Out:
# (19, 28)
#                    Reason Case_Note_Date Caller_ZipCode Caller_Title  \
# 0            Left Message     2015-12-22          10128          NaN
# 3  MTG-Medicaid Home Care     2015-12-22          10023          NaN
# 5     MTG-Legal/Financial     2015-12-22          10010          NaN
#
#           Caller_Mailing_Address Caller_City Caller_State      Service  \
# 0       502 East 88th Street #5C    New York           NY        Admin
# 3    44  West 62 Street, Apt. 8D    New York           NY  Social Work
# 5  4 Peter Cooper Road, Apt. 12D    New York           NY          I/R
#
#   Caller_Borough  Reason_2 Caller_DOB Caller_Date_of_Birth Reason_3  \
# 0      Manhattan       NaN      Given           1955-05-06      NaN
# 3      Manhattan  Planning      Given           1940-01-01      NaN
# 5      Manhattan       NaN      Given           1944-09-30      NaN
#
#    Caller_Age Reason_4 Reason_5 Caller_Gender              Caller_Education  \
# 0          60      NaN      NaN        Female               Bachelor Degree
# 3          75      NaN      NaN        Female  Not Appropriate for the call
# 5          69      NaN      NaN        Female      Post/Professional Degree
#
#   Contact_Type Location Caller_Race Caller_Primary_Language  \
# 0    Follow-up    Phone       White                 English
# 3    Follow-up   Office     Unknown                 English
# 5    Follow-up    Phone       White                 English
#
#   Caller_Secondary_Language  file_num  rec_id  \
# 0                       NaN         1       0
# 3                       NaN         1       3
# 5                       NaN         1       5
#
#                                        addrTuple  \
# 0       (502 East 88th Street #5C, New York, NY)
# 3    (44  West 62 Street, Apt. 8D, New York, NY)
# 5  (4 Peter Cooper Road, Apt. 12D, New York, NY)
#
#                                      addrStr                   geocodes
# 0       502 East 88th Street #5C,New York,NY  (40.7768913, -73.9458435)
# 3    44  West 62 Street, Apt. 8D,New York,NY  (40.7707725, -73.9830891)
# 5  4 Peter Cooper Road, Apt. 12D,New York,NY  (40.7347101, -73.9768136)

# %%
#after all of the daily (or so) files are complete, 
#use the rest of this code to read them all into one file, append the invalid address records to them,
#and then write the whole lot to another csv

# %%
#read in the individual daily files:
callsWithGeos = pd.read_csv("callsFromFile1Rows0to19.csv")
print callsWithGeos.shape
#then add one of these append lines for every daily file you create:
#callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows20to1999.csv"))
#print supsWithGeos.shape
#callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows2000to3999.csv"))
print callsWithGeos.shape
#etc
#then write the whole set out to a single file:
callsWithGeos.to_csv("callsWithGeos.csv",index=False)
# Out:
# (19, 28)
# (19, 28)

# %%
#then read in the whole file and append the invalid address records
#also check whether we ever used the Pennsylvania Ave hack:
callsWithGeos = pd.read_csv("callsWithGeos.csv")
print callsWithGeos.shape
#check that we never used the 1600 Pennsylvania Ave hack
res = Geocoder.geocode("1600 Pennsylvania Ave, Washington, DC")
print res.coordinates
sum(callsWithGeos.geocodes.map(lambda x: x != (38.8791981, -76.9818437)))
# Out:
# (19, 28)
# (38.8791981, -76.9818437)
# 19

# %%
callsWithGeos.head(3)
# Out:
#                    Reason Case_Note_Date  Caller_ZipCode Caller_Title  \
# 0            Left Message     2015-12-22           10128          NaN
# 1  MTG-Medicaid Home Care     2015-12-22           10023          NaN
# 2     MTG-Legal/Financial     2015-12-22           10010          NaN
#
#           Caller_Mailing_Address Caller_City Caller_State      Service  \
# 0       502 East 88th Street #5C    New York           NY        Admin
# 1    44  West 62 Street, Apt. 8D    New York           NY  Social Work
# 2  4 Peter Cooper Road, Apt. 12D    New York           NY          I/R
#
#   Caller_Borough  Reason_2 Caller_DOB Caller_Date_of_Birth Reason_3  \
# 0      Manhattan       NaN      Given           1955-05-06      NaN
# 1      Manhattan  Planning      Given           1940-01-01      NaN
# 2      Manhattan       NaN      Given           1944-09-30      NaN
#
#    Caller_Age Reason_4 Reason_5 Caller_Gender              Caller_Education  \
# 0          60      NaN      NaN        Female               Bachelor Degree
# 1          75      NaN      NaN        Female  Not Appropriate for the call
# 2          69      NaN      NaN        Female      Post/Professional Degree
#
#   Contact_Type Location Caller_Race Caller_Primary_Language  \
# 0    Follow-up    Phone       White                 English
# 1    Follow-up   Office     Unknown                 English
# 2    Follow-up    Phone       White                 English
#
#   Caller_Secondary_Language  file_num  rec_id  \
# 0                       NaN         1       0
# 1                       NaN         1       3
# 2                       NaN         1       5
#
#                                            addrTuple  \
# 0  (u'502 East 88th Street #5C', u'New York', u'NY')
# 1  (u'44  West 62 Street, Apt. 8D', u'New York', ...
# 2  (u'4 Peter Cooper Road, Apt. 12D', u'New York'...
#
#                                      addrStr                          geocodes
# 0       502 East 88th Street #5C,New York,NY         (40.7768913, -73.9458435)
# 1    44  West 62 Street, Apt. 8D,New York,NY  (40.77077250000001, -73.9830891)
# 2  4 Peter Cooper Road, Apt. 12D,New York,NY         (40.7347101, -73.9768136)

# %%
#add the calls with invalid addresses back into the file, with a (0,0) geocode
z = np.zeros(callstonotGeo.shape[0])
callstonotGeo['geocodes'] = zip(z,z)
# Out:
# /Users/tamaraosifchin/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
print callsWithGeos.shape
print callstonotGeo.shape
# Out:
# (19, 28)
# (3818, 28)

# %%
callsWithGeos = callsWithGeos.append(callstonotGeo)
callsWithGeos.shape
# Out:
# (3837, 28)

# %%
all_calls.shape  #number of rows should match number of rows in callsWithGeos at this point
# Out:
# (16712, 27)

# %%
#drop the addr str and address tuple because we don't need them
callsWithGeos.drop('addrTuple',axis=1,inplace=True)
callsWithGeos.drop('addrStr',axis=1,inplace=True)

# %%
#save the lot to a csv
callsWithGeos.to_csv('callsFromFile1AllRowsWithGeos.csv',index=False, encoding='utf-8')
