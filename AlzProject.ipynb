# %%
#for EDA:
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

#for geocoding:
from pygeocoder import Geocoder
from pygeocoder import GeocoderError
import numpy as np
import time

# %matplotlib inline
pd.set_option('display.max_columns', 50)
# Out:
# /Users/tamaraosifchin/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
#read in and concatenate the 3 excel files of call data
all_calls = pd.read_excel("datasci4good_2015-12-22_1_of_3.xls")\
                         .append(pd.read_excel("datasci4good_2015-12-22_2_of_3.xls"))\
                         .append(pd.read_excel("datasci4good_2015-12-22_3_of_3.xls"))

# %%
all_calls.shape
# Out:
# (47302, 23)

# %%
all_calls.head(3)
# Out:
#                                         Reason Case Note Date  \
# 0                                 Left Message     2015-12-22
# 1                     Home Care/Companion/Aide     2015-12-22
# 2  Training-Dementia Care Tx for Professionals     2015-12-22
#
#   [Caller] ZipCode [Caller] Title  [Caller] Mailing Address [Caller] City  \
# 0            10128            NaN  502 East 88th Street #5C      New York
# 1              NaN            NaN                       NaN           NaN
# 2              NaN            NaN                       NaN           NaN
#
#   [Caller] State Service [Caller] Borough Reason 2 [Caller] DOB  \
# 0             NY   Admin        Manhattan      NaN        Given
# 1             NY     I/R              NaN      NaN      Unknown
# 2             NY     I/R              NaN      NaN      Unknown
#
#   [Caller] Date of Birth Reason 3  [Caller] Age Reason 4 Reason 5  \
# 0    1955-05-06 00:00:00      NaN            60      NaN      NaN
# 1                    NaN      NaN           NaN      NaN      NaN
# 2                    NaN      NaN           NaN      NaN      NaN
#
#   [Caller] Gender            [Caller] Education Contact Type Location  \
# 0          Female               Bachelor Degree    Follow-up    Phone
# 1         Unknown  Not Appropriate for the call          New    Phone
# 2         Unknown  Not Appropriate for the call          New    Phone
#
#   [Caller] Race [Caller] Primary Language [Caller] Secondary Language
# 0         White                   English                         NaN
# 1       Unknown                   English                         NaN
# 2       Unknown                   English                         NaN

# %%
all_calls.rename(columns=lambda x: x.replace(" ","_"),inplace=True)
all_calls.rename(columns=lambda x: x.replace("[",""),inplace=True)
all_calls.rename(columns=lambda x: x.replace("]",""),inplace=True)

# %%
all_calls.columns.values
# Out:
# array([u'Reason', u'Case_Note_Date', u'Caller_ZipCode', u'Caller_Title',
#        u'Caller_Mailing_Address', u'Caller_City', u'Caller_State',
#        u'Service', u'Caller_Borough', u'Reason_2', u'Caller_DOB',
#        u'Caller_Date_of_Birth', u'Reason_3', u'Caller_Age', u'Reason_4',
#        u'Reason_5', u'Caller_Gender', u'Caller_Education', u'Contact_Type',
#        u'Location', u'Caller_Race', u'Caller_Primary_Language',
#        u'Caller_Secondary_Language'], dtype=object)

# %%
print sum(all_calls.Caller_Borough.value_counts())
all_calls.Caller_Borough.value_counts()
# Out:
# 33674
# Manhattan        12588
# Brooklyn          8192
# Queens            7439
# Bronx             4521
# Staten Island      934
# dtype: int64

# %%
sum(all_calls[all_calls.Caller_Borough == 'Staten Island'].Caller_Mailing_Address.isnull())
# Out:
# 72

# %%
all_calls.head(3)
# Out:
#                                         Reason Case_Note_Date Caller_ZipCode  \
# 0                                 Left Message     2015-12-22          10128
# 1                     Home Care/Companion/Aide     2015-12-22            NaN
# 2  Training-Dementia Care Tx for Professionals     2015-12-22            NaN
#
#   Caller_Title    Caller_Mailing_Address Caller_City Caller_State Service  \
# 0          NaN  502 East 88th Street #5C    New York           NY   Admin
# 1          NaN                       NaN         NaN           NY     I/R
# 2          NaN                       NaN         NaN           NY     I/R
#
#   Caller_Borough Reason_2 Caller_DOB Caller_Date_of_Birth Reason_3  \
# 0      Manhattan      NaN      Given  1955-05-06 00:00:00      NaN
# 1            NaN      NaN    Unknown                  NaN      NaN
# 2            NaN      NaN    Unknown                  NaN      NaN
#
#    Caller_Age Reason_4 Reason_5 Caller_Gender              Caller_Education  \
# 0          60      NaN      NaN        Female               Bachelor Degree
# 1         NaN      NaN      NaN       Unknown  Not Appropriate for the call
# 2         NaN      NaN      NaN       Unknown  Not Appropriate for the call
#
#   Contact_Type Location Caller_Race Caller_Primary_Language  \
# 0    Follow-up    Phone       White                 English
# 1          New    Phone     Unknown                 English
# 2          New    Phone     Unknown                 English
#
#   Caller_Secondary_Language
# 0                       NaN
# 1                       NaN
# 2                       NaN

# %%
sum(all_calls.Caller_Mailing_Address.isnull())
# Out:
# 9603

# %%
all_calls.Caller_State.value_counts()
# Out:
# NY    45220
# NJ      581
# CA      163
# MA      143
# FL      134
# CT      133
# NC      103
# PA       96
# MD       95
# TX       66
# VA       63
# DC       50
# GA       49
# NM       26
# SC       23
# CO       23
# OH       15
# MN       15
# WA       13
# ME       13
# OR       13
# AL       13
# IL       12
# RI       12
# AZ       11
# MI        9
# VT        9
# MO        6
# TN        6
# WV        3
# WI        3
# PR        3
# NV        3
# ND        2
# LA        2
# AR        1
# NU        1
# DE        1
# ID        1
# NH        1
# NL        1
# IN        1
# dtype: int64

# %%
all_calls.Caller_City.value_counts()
# Out:
# New York                  12475
# Brooklyn                   8618
# Bronx                      4792
# Staten Island               957
# Flushing                    895
# Jamaica                     761
# Forest Hills                545
# Astoria                     409
# Woodside                    369
# Jackson Heights             352
# Bayside                     291
# Elmhurst                    257
# East Elmhurst               236
# Far Rockaway                211
# Ridgewood                   203
# Rosedale                    200
# Rego Park                   186
# Long Island City            183
# Sunnyside                   174
# Fresh Meadows               166
# Corona                      156
# Howard Beach                156
# Kew Gardens                 155
# Queens Village              150
# NYC                         138
# Whitestone                  137
# Maspeth                     115
# Ozone Park                  112
# South Richmond Hill         106
# Springfield Gardens         106
#                           ...
# Amherst                       1
# South Ozone park              1
# Demarest                      1
# Barnegat                      1
# Deer Park, Long Island        1
# Greenlawn                     1
# Red Bank                      1
# Beverly                       1
# Dobbs Ferry                   1
# East Rockaway                 1
# Springfield Garden            1
# Putnam Valley                 1
# Beechurst                     1
# Ewing                         1
# Masbeth                       1
# Williamsburg                  1
# Schenevus                     1
# Long lsland                   1
# Montgomeryville               1
# St Paul                       1
# Pound Ridge                   1
# Tappan                        1
# Fresh Meadow                  1
# Whiting                       1
# everett                       1
# Williston                     1
# Sandpoint                     1
# Shrewsbury                    1
# Buffalo                       1
# Prosper                       1
# dtype: int64

# %%
ny_calls = all_calls[all_calls.Caller_State == 'NY']
ny_calls.Caller_City.value_counts()
# Out:
# New York                  12460
# Brooklyn                   8613
# Bronx                      4784
# Staten Island               957
# Flushing                    895
# Jamaica                     761
# Forest Hills                545
# Astoria                     405
# Woodside                    369
# Jackson Heights             352
# Bayside                     291
# Elmhurst                    257
# East Elmhurst               236
# Far Rockaway                211
# Rosedale                    200
# Ridgewood                   196
# Rego Park                   186
# Long Island City            183
# Sunnyside                   174
# Fresh Meadows               166
# Corona                      156
# Howard Beach                156
# Kew Gardens                 155
# Queens Village              150
# NYC                         138
# Whitestone                  137
# Maspeth                     115
# Ozone Park                  112
# Woodhaven                   106
# Springfield Gardens         106
#                           ...
# Croton-on-Hudson              1
# Millwood                      1
# Williamsburg                  1
# Long Island                   1
# Putnam Valley                 1
# East Rockaway                 1
# Warwick                       1
# Greenlawn                     1
# Bron                          1
# Peoria                        1
# Woodheaven                    1
# Garner Ville                  1
# Ditmas Park                   1
# New York, Astoria             1
# Long Valley                   1
# Peekskill                     1
# Getzville                     1
# Hudson                        1
# Sleepy Hollow                 1
# Hawthorne                     1
# Carona                        1
# Lynbrook                      1
# Deer Park, Long Island        1
# South Salem                   1
# Manhasset                     1
# East Patchogue                1
# Richmond Hills                1
# Uniondale                     1
# Victor                        1
# Mount Kisco                   1
# dtype: int64

# %%
sns.countplot(x="Caller_Borough", data=all_calls, palette="Greens_4d")

# %%
###########
#Here's the code to read in a single excel file and make a call to google for the geocodes, 2300 per execution,
#one address per call:
###########

# %%
#read in one excel file of call data
all_calls = pd.read_excel("datasci4good_2015-12-22_1_of_3.xls")
                         #Tamara to take: ("datasci4good_2015-12-22_2_of_3.xls"))\
                         #Gordon or Brian to take:("datasci4good_2015-12-22_3_of_3.xls"))

# %%
#rename columns so they are easier to work with
all_calls.rename(columns=lambda x: x.replace(" ","_"),inplace=True)
all_calls.rename(columns=lambda x: x.replace("[",""),inplace=True)
all_calls.rename(columns=lambda x: x.replace("]",""),inplace=True)

# %%
#add columns for id number in case we ever have to put the records back in the original order
num_file = 1 #change to 2 and 3 for 2nd and 3rd files
all_calls['file_num'] = num_file
rec_num = range(0,len(all_calls),1)
all_calls['rec_id'] = rec_num

# %%
all_calls.head(3)
# Out:
#                                         Reason Case_Note_Date Caller_ZipCode  \
# 0                                 Left Message     2015-12-22          10128
# 1                     Home Care/Companion/Aide     2015-12-22            NaN
# 2  Training-Dementia Care Tx for Professionals     2015-12-22            NaN
#
#   Caller_Title    Caller_Mailing_Address Caller_City Caller_State Service  \
# 0          NaN  502 East 88th Street #5C    New York           NY   Admin
# 1          NaN                       NaN         NaN           NY     I/R
# 2          NaN                       NaN         NaN           NY     I/R
#
#   Caller_Borough Reason_2 Caller_DOB Caller_Date_of_Birth Reason_3  \
# 0      Manhattan      NaN      Given           1955-05-06      NaN
# 1            NaN      NaN    Unknown                  NaT      NaN
# 2            NaN      NaN    Unknown                  NaT      NaN
#
#    Caller_Age Reason_4 Reason_5 Caller_Gender              Caller_Education  \
# 0          60      NaN      NaN        Female               Bachelor Degree
# 1         NaN      NaN      NaN       Unknown  Not Appropriate for the call
# 2         NaN      NaN      NaN       Unknown  Not Appropriate for the call
#
#   Contact_Type Location Caller_Race Caller_Primary_Language  \
# 0    Follow-up    Phone       White                 English
# 1          New    Phone     Unknown                 English
# 2          New    Phone     Unknown                 English
#
#   Caller_Secondary_Language  file_num  rec_id
# 0                       NaN         1       0
# 1                       NaN         1       1
# 2                       NaN         1       2

# %%
#split into 2 files for eto and cn
#next time split at 8001 so the first file ends at 8000 not 7999
#all_calls[:8000].to_csv("datasci4good_2015-12-22_1_of_3_eto.csv",index=False, encoding='utf-8')
#all_calls[8000:].to_csv("datasci4good_2015-12-22_1_of_3_cn.csv",index=False, encoding='utf-8')

# %%
###########
#First some code to weed out the invalid addresses (i.e. those missing 2 of 3 address fields)
###########

# %%
#check where the floats are that are messing up the map function a few cells down.  Python raises an error
#when it tries to take the len of a float.  ie len(NaN)
all_calls['addrTuple'] = zip(all_calls.Caller_Mailing_Address,all_calls.Caller_City, all_calls.Caller_State)
floats = map(lambda x: (type(x[0]) == float) |(type(x[1]) == float) |(type(x[2]) == float), all_calls.addrTuple)
all_calls[floats]
# Out:
#                                             Reason Case_Note_Date  \
# 0                        Alz Disease Organizations     2015-03-05
# 15                           ESS - Groups/Programs     2015-03-05
# 26                          MTG-Medicaid Home Care     2015-03-05
# 27                          MTG-Medicaid Home Care     2015-03-05
# 28              Training-Family Caregiver Workshop     2015-03-05
# 36                      MTG-Understanding Dementia     2015-03-05
# 37                                           Other     2015-03-05
# 55                       Alz Disease Organizations     2015-03-05
# 57                                    Left Message     2015-03-05
# 58                                    Left Message     2015-03-05
# 59                                        Medicare     2015-03-05
# 61                        Home Care/Companion/Aide     2015-03-04
# 63                                        Planning     2015-03-04
# 64                                       Diagnosis     2015-03-04
# 65                        CG Stress/Needed to Talk     2015-03-04
# 68                        CG Stress/Needed to Talk     2015-03-04
# 70                     MTG-Monthly Educational Mtg     2015-03-04
# 71     Training-Dementia Care Tx for Professionals     2015-03-04
# 72                     MTG-Monthly Educational Mtg     2015-03-04
# 73                     MTG-Monthly Educational Mtg     2015-03-04
# 76                       LTC Facility/Nursing Home     2015-03-04
# 78                      MTG-Understanding Dementia     2015-03-04
# 83                        CG Stress/Needed to Talk     2015-03-04
# 88     Training-Dementia Care Tx for Professionals     2015-03-04
# 94                                   Support Group     2015-02-23
# 96                                   Support Group     2015-02-23
# 99                                   Support Group     2015-02-23
# 106                    MTG-Monthly Educational Mtg     2015-03-04
# 108                                 Special Events     2015-03-04
# 111                       CG Stress/Needed to Talk     2015-03-04
# ...                                            ...            ...
# 16513                           Adult Day Programs     2014-04-29
# 16544            NaN          NaN                    NaN         NaN
# 16545            NaN          NaN                    NaN         NaN
# 16548            NaN          NaN                    NaN         NaN
# 16560            NaN          NaN                    NaN         NaN
# 16565            NaN          NaN                    NaN         NaN
# 16566            NaN          NaN                    NaN         NaN
# 16567            NaN          NaN                    NaN         NaN
# 16568            NaN          NaN                    NaN         NaN
# 16569            NaN          NaN                    NaN         NaN
# 16573            NaN          NaN                    NaN         NaN
# 16574            NaN          NaN                    NaN         NaN
# 16576            NaN          NaN                    NaN         NaN
# 16580            NaN          NaN                    NaN         NaN
# 16591          11203          NaN                    NaN         NaN
# 16593            NaN          NaN                    NaN         NaN
# 16595          10028          NaN                    NaN    New York
# 16596            NaN          NaN                    NaN         NaN
# 16597            NaN          NaN                    NaN         NaN
# 16598            NaN          NaN                    NaN         NaN
# 16615            NaN          NaN                    NaN         NaN
# 16653            NaN          NaN                    NaN         NaN
# 16655            NaN          NaN                    NaN         NaN
# 16657          10462          NaN                    NaN       Bronx
#
#       Caller_State                             Service Caller_Borough  \
# 0               NY                                 I/R            NaN
# 15              NY                                 I/R      Manhattan
# 26              NY                                 I/R            NaN
# 27              NY                                 I/R            NaN
# 28              NY                                 I/R            NaN
# 36              NY                                 I/R            NaN
# 37              NY                                 I/R            NaN
# 55              NY                                 I/R            NaN
# 57              NY                               Admin            NaN
# 58              NY                               Admin         Queens
# 59              NY                Contact Center - I/R         Queens
# 61              NY                Contact Center - I/R            NaN
# 63              NY  Contact Center - Care Consultation            NaN
# 64              NY                                 I/R            NaN
# 65              NY                                 I/R         Queens
# 68              NY                Contact Center - I/R         Queens
# 70              NY                                 I/R      Manhattan
# 71              NY                                 I/R       Brooklyn
# 72              NY                                 I/R            NaN
# 73              NY                                 I/R            NaN
# 76              NY                 Care Consultation 1            NaN
# 78              NY                                 I/R          Bronx
# 83              NY                Contact Center - I/R            NaN
# 88              NY                                 I/R            NaN
# 94              NY                 Care Consultation 1       Brooklyn
# 96              NY                 Care Consultation 1      Manhattan
# 99              NY                 Care Consultation 1      Manhattan
# 106             NY                                 I/R            NaN
# 108             NY                                 I/R            NaN
# 111             FL                Contact Center - I/R            NaN
# ...            ...                                 ...            ...
# 16513           NY                                 I/R            NaN
# 16514           NY                 Care Consultation 1         Queens
# 16516           NY                                 I/R            NaN
# 16525           NY                                 I/R            NaN
# 16526           NY                 Care Consultation 1            NaN
# 16530           NY                                 I/R            NaN
# 16541           NY                                 I/R            NaN
# 16544           NY                 Care Consultation 1      Manhattan
# 16545           NY                 Care Consultation 1      Manhattan
# 16548           NY                 Care Consultation 1         Queens
# 16560           NY                                 I/R            NaN
# 16565           NY                 Care Consultation 1      Manhattan
# 16566           NY                                 I/R            NaN
# 16567           NY                                 I/R            NaN
# 16568           NY                                 I/R            NaN
# 16569           NY                 Care Consultation 1      Manhattan
# 16573           NY                                 I/R            NaN
# 16574           NY                                 I/R      Manhattan
# 16576           NY                 Care Consultation 1      Manhattan
# 16580           NY                 Care Consultation 1         Queens
# 16591           NY                                 I/R       Brooklyn
# 16593           NY                 Care Consultation 1      Manhattan
# 16595           NY                 Care Consultation 1      Manhattan
# 16596           NY                                 I/R            NaN
# 16597           NY                 Care Consultation 1       Brooklyn
# 16598           NY                                 I/R            NaN
# 16615           NY                                 I/R            NaN
# 16653           NY                                 I/R          Bronx
# 16655           NY                                 I/R            NaN
# 16657           NY                                 I/R          Bronx
#
#                         Reason_2 Caller_DOB Caller_Date_of_Birth  \
# 0                            NaN    Unknown                  NaN
# 15                           NaN    Unknown                  NaN
# 26                           NaN    Unknown                  NaN
# 27                           NaN    Unknown                  NaN
# 28                           NaN    Refused                  NaN
# 36                           NaN    Unknown                  NaN
# 37                           NaN    Unknown                  NaN
# 55                           NaN    Unknown                  NaN
# 57                           NaN    Unknown                  NaN
# 58                           NaN    Unknown                  NaN
# 59                      Medicaid    Unknown                  NaN
# 61                           NaN    Unknown                  NaN
# 63                           NaN    Unknown                  NaN
# 64      CG Stress/Needed to Talk    Unknown                  NaN
# 65                           NaN    Unknown                  NaN
# 68                           NaN    Unknown                  NaN
# 70                           NaN    Unknown                  NaN
# 71                           NaN    Unknown                  NaN
# 72                           NaN    Unknown                  NaN
# 73                           NaN    Unknown                  NaN
# 76                           NaN    Unknown                  NaN
# 78                           NaN    Unknown                  NaN
# 83                           NaN    Unknown                  NaN
# 88                           NaN    Unknown                  NaN
# 94                           NaN    Unknown                  NaN
# 96                           NaN    Unknown                  NaN
# 99                           NaN    Unknown                  NaN
# 106                          NaN    Unknown                  NaN
# 108                          NaN    Unknown                  NaN
# 111                          NaN    Unknown                  NaN
# ...                          ...        ...                  ...
# 16513                        NaN    Unknown                  NaN
# 16514   CG Stress/Needed to Talk    Unknown                  NaN
# 16516                        NaN    Unknown                  NaN
# 16525                        NaN    Unknown                  NaN
# 16526                        NaN    Unknown                  NaN
# 16530                        NaN    Unknown                  NaN
# 16541                        NaN    Unknown                  NaN
# 16544                        NaN    Unknown                  NaN
# 16545                        NaN    Unknown                  NaN
# 16548                        NaN    Unknown                  NaN
# 16560                        NaN    Unknown                  NaN
# 16565                        NaN    Unknown                  NaN
# 16566  LTC Facility/Nursing Home    Unknown                  NaN
# 16567                        NaN    Unknown                  NaN
# 16568                        NaN    Unknown                  NaN
# 16569                        NaN    Unknown                  NaN
# 16573                   Genetics    Unknown                  NaN
# 16574                        NaN    Unknown                  NaN
# 16576                        NaN    Unknown                  NaN
# 16580                        NaN    Unknown                  NaN
# 16591               Alz NYC Info    Unknown                  NaN
# 16593                        NaN    Unknown                  NaN
# 16595                        NaN    Unknown                  NaN
# 16596                        NaN    Unknown                  NaN
# 16597                        NaN    Unknown                  NaN
# 16598                        NaN    Unknown                  NaN
# 16615      Behaviors - Wandering    Unknown                  NaN
# 16653                        NaN    Unknown                  NaN
# 16655                        NaN    Unknown                  NaN
# 16657       Professional Consult    Unknown                  NaN
#
# 16573                       NaN         2   16573
# 16574                       NaN         2   16574
# 16576                       NaN         2   16576
# 16580                       NaN         2   16580
# 16591                       NaN         2   16591
# 16593                       NaN         2   16593
# 16595                       NaN         2   16595
# 16596                       NaN         2   16596
# 16597                       NaN         2   16597
# 16598                       NaN         2   16598
# 16615                       NaN         2   16615
# 16653                       NaN         2   16653
# 16655                       NaN         2   16655
# 16657                       NaN         2   16657
#
#                               addrTuple
# 0                        (nan, nan, NY)
# 15     (605 Park Ave., #10065, nan, NY)
# 26                       (nan, nan, NY)
# 27                       (nan, nan, NY)
# 28                       (nan, nan, NY)
# 36                       (nan, nan, NY)
# 37                       (nan, nan, NY)
# 55                       (nan, nan, NY)
# 57                       (nan, nan, NY)
# 58                   (nan, Astoria, NY)
# 59                   (nan, Astoria, NY)
# 61                       (nan, nan, NY)
# 63                       (nan, nan, NY)
# 64                       (nan, nan, NY)
# 65                       (nan, nan, NY)
# 68                       (nan, nan, NY)
# 70                       (nan, nan, NY)
# 71        (10 Stratford Rd 9g, nan, NY)
# 72                       (nan, nan, NY)
# 73                       (nan, nan, NY)
# 76                       (nan, nan, NY)
# 78                       (nan, nan, NY)
# 83                       (nan, nan, NY)
# 88                       (nan, nan, NY)
# 94                       (nan, nan, NY)
# 96                       (nan, nan, NY)
# 99                       (nan, nan, NY)
# 106                      (nan, nan, NY)
# 108                      (nan, nan, NY)
# 111                      (nan, nan, FL)
# ...                                 ...
# 16513                    (nan, nan, NY)
# 16514                    (nan, nan, NY)
# 16516                    (nan, nan, NY)
# 16525                    (nan, nan, NY)
# 16526                    (nan, nan, NY)
# 16530                    (nan, nan, NY)
# 16541                    (nan, nan, NY)
# 16544                    (nan, nan, NY)
# 16545                    (nan, nan, NY)
# 16548                    (nan, nan, NY)
# 16560                    (nan, nan, NY)
# 16565                    (nan, nan, NY)
# 16566                    (nan, nan, NY)
# 16567                    (nan, nan, NY)
# 16568                    (nan, nan, NY)
# 16569                    (nan, nan, NY)
# 16573                    (nan, nan, NY)
# 16574                    (nan, nan, NY)
# 16576                    (nan, nan, NY)
# 16580                    (nan, nan, NY)
# 16591                    (nan, nan, NY)
# 16593                    (nan, nan, NY)
# 16595               (nan, New York, NY)
# 16596                    (nan, nan, NY)
# 16597                    (nan, nan, NY)
# 16598                    (nan, nan, NY)
# 16615                    (nan, nan, NY)
# 16653                    (nan, nan, NY)
# 16655                    (nan, nan, NY)
# 16657                  (nan, Bronx, NY)
#
# [3376 rows x 26 columns]

# %%
#replace the NaNs with empty strings.  The NaNs generated an error in the map function below when I tried to get the 
#len of the value NaN
all_calls.Caller_Mailing_Address = all_calls.Caller_Mailing_Address.fillna("")
all_calls.Caller_City = all_calls.Caller_City.fillna("")
all_calls.Caller_State = all_calls.Caller_State.fillna("")

# %%
#floats(aka NaNs) should be gone now
all_calls['addrTuple'] = zip(all_calls.Caller_Mailing_Address,all_calls.Caller_City, all_calls.Caller_State)
floats = map(lambda x: (type(x[0]) == float) |(type(x[1]) == float) |(type(x[2]) == float), all_calls.addrTuple)
all_calls[floats]
# Out:
# Empty DataFrame
# Columns: [Reason, Case_Note_Date, Caller_ZipCode, Caller_Title, Caller_Mailing_Address, Caller_City, Caller_State, Service, Caller_Borough, Reason_2, Caller_DOB, Caller_Date_of_Birth, Reason_3, Caller_Age, Reason_4, Reason_5, Caller_Gender, Caller_Education, Contact_Type, Location, Caller_Race, Caller_Primary_Language, Caller_Secondary_Language, file_num, rec_id, addrTuple]
# Index: []

# %%
#concatenate the address fields into one string to simplify the eventual request to google
all_calls['addrStr'] = all_calls.Caller_Mailing_Address + ","+ all_calls.Caller_City + "," + all_calls.Caller_State

# %%
# pull records from all_calls where there is a non-null address, will get geocode on those

#will consider an address with either a street and city or a city and state to be a non-null address
#but this doesn't filter out other types of invalid addresses;  
#the getGeo function should really handle those...someday

nonnullAddr = all_calls.addrTuple.map(lambda x: (((len(x[0]) > 0) & (len(x[1]) > 0))) \
                                      | ((len(x[1]) > 0) & (len(x[2]) > 0)))

print len(nonnullAddr)
print sum(nonnullAddr)
callstoGeo = all_calls[nonnullAddr]
print "toGeo: ", callstoGeo.shape
callstonotGeo = all_calls[-nonnullAddr]
print "tonotGeo:", callstonotGeo.shape
# Out:
# 16669
# 13642
# toGeo:  (13642, 27)
# tonotGeo: (3027, 27)

# %%
#function that slows down the request rate so that google doesn't reject them 
#should really be written as a try and except clause that catches over limit error as well as invalid address
#but this will do for now

#function that slows down the request rate so that google doesn't reject me 
#also allows google to return an empty result
def getGeo(addr):
    try:
        time.sleep(1)
        res = Geocoder.geocode(addr)
    except GeocoderError:  #really needs to catch the over limit error but will worry about that another day
        res = Geocoder.geocode("1600 Pennsylvania Ave, Washington, DC") #total hack
        
    return res

# %%
#I just changed the row numbers every time I ran this because I did not
#know when my daily limit would be up.  I ran a few hundred rows at a time when I did this for weeSpring.
#I tried it out on 20 rows this morning.
callstoGeoToday = callstoGeo.iloc[13600:13642,:]
callstoGeoToday['geocodes'] = callstoGeoToday['addrStr'].map(lambda x: getGeo(x)).map(lambda y: y.coordinates)
callstoGeoToday['geocodes']
# Out:
# /Users/tamaraosifchin/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 16625      (40.939537, -73.732441)
# 16626    (40.6965499, -73.9882929)
# 16627    (40.6965499, -73.9882929)
# 16628     (26.594091, -82.0320799)
# 16629    (40.7592495, -73.9048265)
# 16630    (40.7592495, -73.9048265)
# 16631    (40.7500992, -73.8939711)
# 16632      (40.872007, -73.851443)
# 16633      (40.676755, -73.729022)
# 16634    (40.8654846, -73.8464683)
# 16635      (40.746428, -74.000044)
# 16636    (40.7280129, -73.9876668)
# 16637    (40.7127837, -74.0059413)
# 16638    (40.8654846, -73.8464683)
# 16639       (40.553712, -74.15852)
# 16640       (40.67158, -73.883077)
# 16641    (40.7127837, -74.0059413)
# 16642    (40.7127837, -74.0059413)
# 16643    (40.7937121, -73.9732282)
# 16644    (40.7500992, -73.8939711)
# 16645    (40.7347101, -73.9768136)
# 16646      (40.721566, -73.979783)
# 16647    (40.6734787, -73.9446093)
# 16648    (40.6743618, -73.9745353)
# 16649    (40.8827385, -73.8924873)
# 16650      (33.58414, -117.651005)
# 16651    (40.7245438, -73.8486837)
# 16652    (40.7713024, -73.9632393)
# 16654      (40.629097, -74.136666)
# 16656    (40.3765384, -74.6026784)
# 16657    (40.8370495, -73.8654295)
# 16658     (40.906442, -73.9066696)
# 16659    (40.6674819, -73.9201088)
# 16660      (40.580568, -73.940554)
# 16661    (40.7929916, -73.9685133)
# 16662      (40.665891, -73.955158)
# 16663    (40.8848756, -73.8651345)
# 16664      (40.884185, -73.911854)
# 16665     (40.714891, -73.6826132)
# 16666      (40.727978, -73.626191)
# 16667      (40.643786, -73.949499)
# 16668      (40.805727, -73.491452)
# Name: geocodes, dtype: object

# %%
#save each batch of data to a csv
callstoGeoToday.to_csv('callsFromFile2Rows13600to13641.csv',index=False)

# %%
callstoGeo.iloc[13641]
# Out:
# Reason                                              Medical
# Case_Note_Date                          2014-04-25 00:00:00
# Caller_ZipCode                                        11791
# Caller_Title                                            NaN
# Caller_Mailing_Address                      56 Park Drive E
# Caller_City                                         Syosset
# Caller_State                                             NY
# Service                                                 I/R
# Caller_Borough                                          NaN
# Reason_2                                       Alz NYC Info
# Caller_DOB                                          Unknown
# Caller_Date_of_Birth                                    NaN
# Reason_3                                                NaN
# Caller_Age                                              NaN
# Reason_4                                                NaN
# Reason_5                                                NaN
# Caller_Gender                                        Female
# Caller_Education               Not Appropriate for the call
# Contact_Type                                      Follow-up
# Location                                              Phone
# Caller_Race                                         Unknown
# Caller_Primary_Language                             English
# Caller_Secondary_Language                               NaN
# file_num                                                  2
# rec_id                                                16668
# addrTuple                    (56 Park Drive E, Syosset, NY)
# addrStr                          56 Park Drive E,Syosset,NY
# Name: 16668, dtype: object

# %%
print callstoGeoToday.shape
callstoGeoToday.head(3)
# Out:
# (1000, 28)
#                                           Reason Case_Note_Date  \
# 1296  MTG-Moving Your Relative to A Nursing Home     2015-02-12
# 1299                                       Other     2015-02-12
# 1300                    CG Stress/Needed to Talk     2015-02-12
#
#      Caller_ZipCode Caller_Title         Caller_Mailing_Address Caller_City  \
# 1296          10128          NaN         222 E. 9 St., Apt. 39J    New York
# 1299          10019          NaN  3 Columbus Circle, 16th Floor    New York
# 1300          10019          NaN      250 West 50th St., Apt 4C    New York
#
#      Caller_State               Service Caller_Borough Reason_2 Caller_DOB  \
# 1296           NY  Contact Center - I/R      Manhattan      NaN      Given
# 1299           NY  Contact Center - I/R      Manhattan      NaN    Refused
# 1300           NY  Contact Center - I/R            NaN      NaN      Given
#
#      Caller_Date_of_Birth Reason_3  Caller_Age Reason_4 Reason_5  \
# 1296  1947-05-26 00:00:00      NaN          67      NaN      NaN
# 1299                  NaN      NaN         NaN      NaN      NaN
# 1300  1969-06-25 00:00:00      NaN          43      NaN      NaN
#
#      Caller_Gender              Caller_Education Contact_Type Location  \
# 1296        Female  Not Appropriate for the call    Follow-up    Phone
# 1299        Female      Post/Professional Degree    Follow-up    Phone
# 1300        Female  Not Appropriate for the call    Follow-up    Phone
#
#           Caller_Race Caller_Primary_Language Caller_Secondary_Language  \
# 1296            White                 English                       NaN
# 1299  Hispanic/Latino                 English                       NaN
# 1300  Hispanic/Latino                 English                       NaN
#
#       file_num  rec_id                                      addrTuple  \
# 1296         2    1296         (222 E. 9 St., Apt. 39J, New York, NY)
# 1299         2    1299  (3 Columbus Circle, 16th Floor, New York, NY)
# 1300         2    1300      (250 West 50th St., Apt 4C, New York, NY)
#
#                                         addrStr                   geocodes
# 1296         222 E. 9 St., Apt. 39J,New York,NY   (40.729939, -73.9890928)
# 1299  3 Columbus Circle, 16th Floor,New York,NY  (40.7668837, -73.9822441)
# 1300      250 West 50th St., Apt 4C,New York,NY  (40.7618461, -73.9858036)

# %%
#after all of the daily (or so) files are complete, 
#use the rest of this code to read them all into one file, append the invalid address records to them,
#and then write the whole lot to another csv

# %%
#read in the individual daily files:
callsWithGeos = pd.read_csv("callsFromFile2Rows0to999.csv")
print callsWithGeos.shape
#then add one of these append lines for every daily file you create:
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows1000to1999.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows2000to2399.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows2400to3399.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows3400to4499.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows4400to4799.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows4800to4899.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows4900to5899.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows5900to6399.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows6400to7399.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows7400to8399.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows8400to9399.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows9400to9799.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows9800to10799.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows10800to11799.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows11800to12199.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows12200to13599.csv"))
print callsWithGeos.shape
callsWithGeos = callsWithGeos.append(pd.read_csv("callsFromFile2Rows13600to13641.csv"))
print callsWithGeos.shape
#etc
#then write the whole set out to a single file:
callsWithGeos.to_csv("callsWithGeos.csv",index=False)
# Out:
# (1000, 28)
# (2000, 28)
# (2400, 28)
# (3400, 28)
# (4400, 28)
# (4800, 28)
# (4900, 28)
# (5900, 28)
# (6400, 28)
# (7400, 28)
# (8400, 28)
# (9400, 28)
# (9800, 28)
# (10800, 28)
# (11800, 28)
# (12200, 28)
# (13600, 28)
# (13642, 28)

# %%
#then read in the whole file and append the invalid address records
#also check whether we ever used the Pennsylvania Ave hack:
callsWithGeos = pd.read_csv("callsWithGeos.csv")
print callsWithGeos.shape
#check that we never used the 1600 Pennsylvania Ave hack
res = Geocoder.geocode("1600 Pennsylvania Ave, Washington, DC")
print res.coordinates
sum(callsWithGeos.geocodes.map(lambda x: x != (38.8791981, -76.9818437)))
# Out:
# (13642, 28)
# (38.8791981, -76.9818437)
# 13642

# %%
callsWithGeos.head(3)
# Out:
#                        Reason Case_Note_Date Caller_ZipCode Caller_Title  \
# 0  MTG-Understanding Dementia     2015-03-05          10036          NaN
# 1  MTG-Understanding Dementia     2015-03-05          10036          NaN
# 2    CG Stress/Needed to Talk     2015-03-05          10314          NaN
#
#   Caller_Mailing_Address    Caller_City Caller_State               Service  \
# 0          413 W 46th St       New York           NY                   I/R
# 1          413 W 46th St       New York           NY  Contact Center - I/R
# 2          90 Gwenn Loop  Staten Island           NY  Contact Center - I/R
#
#   Caller_Borough Reason_2 Caller_DOB Caller_Date_of_Birth Reason_3  \
# 0      Manhattan      NaN    Unknown                  NaN      NaN
# 1      Manhattan      NaN    Unknown                  NaN      NaN
# 2  Staten Island      NaN      Given  1953-01-01 00:00:00      NaN
#
#    Caller_Age Reason_4 Reason_5 Caller_Gender              Caller_Education  \
# 0         NaN      NaN      NaN          Male  Not Appropriate for the call
# 1         NaN      NaN      NaN          Male  Not Appropriate for the call
# 2          62      NaN      NaN        Female          High School Graduate
#
#   Contact_Type Location      Caller_Race Caller_Primary_Language  \
# 0    Follow-up    Phone  Hispanic/Latino                 English
# 1          New    Phone  Hispanic/Latino                 English
# 2    Follow-up    Phone            White                 English
#
#   Caller_Secondary_Language  file_num  rec_id  \
# 0                       NaN         2       1
# 1                       NaN         2       2
# 2                       NaN         2       3
#
#                                      addrTuple  \
# 0       (u'413 W 46th St', u'New York', u'NY')
# 1       (u'413 W 46th St', u'New York', u'NY')
# 2  (u'90 Gwenn Loop', u'Staten Island', u'NY')
#
#                           addrStr                          geocodes
# 0       413 W 46th St,New York,NY         (40.7613728, -73.9912909)
# 1       413 W 46th St,New York,NY         (40.7613728, -73.9912909)
# 2  90 Gwenn Loop,Staten Island,NY  (40.5889359, -74.14389129999999)

# %%
#add the calls with invalid addresses back into the file, with a (0,0) geocode
z = np.zeros(callstonotGeo.shape[0])
callstonotGeo['geocodes'] = zip(z,z)
# Out:
# /Users/tamaraosifchin/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
print callsWithGeos.shape
print callstonotGeo.shape
# Out:
# (13642, 28)
# (3027, 28)

# %%
callsWithGeos = callsWithGeos.append(callstonotGeo)
callsWithGeos.shape
# Out:
# (16669, 28)

# %%
all_calls.shape  #number of rows should match number of rows in callsWithGeos at this point
# Out:
# (16669, 27)

# %%
#drop the addr str and address tuple because we don't need them
callsWithGeos.drop('addrTuple',axis=1,inplace=True)
callsWithGeos.drop('addrStr',axis=1,inplace=True)

# %%
#this code breaks the (lat,lon) tuple into lat and lon columns
#break the geocode into lat and long so we can plot it with CartoDB
callsWithGeos.geocodes = callsWithGeos.geocodes.str.replace('(','')
callsWithGeos.geocodes = callsWithGeos.geocodes.str.replace(')','')

#this code is copied from the web.  No simple solution.
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in callsWithGeos['geocodes']:
    # Try to,
    try:
        # Split the row by comma, convert to float, and append
        # everything before the comma to lat
        lat.append(float(row.split(',')[0]))
        # Split the row by comma, convert to float, and append
        # everything after the comma to lon
        lon.append(float(row.split(',')[1]))
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)

# Create two new columns from lat and lon
callsWithGeos['latitude'] = lat
callsWithGeos['longitude'] = lon

# %%
#save the lot to a csv
callsWithGeos.to_csv('callsFromFile2AllRowsWithGeos.csv',index=False, encoding='utf-8')
